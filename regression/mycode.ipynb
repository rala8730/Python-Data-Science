# %%
import pandas
import numpy
import matplotlib as plt

from sklearn import linear_model, feature_extraction

def categorical_features(row):
    d = {}
    d["STATE"] = row[1]["STATE"]
    return d
#feature
def last_poll(full_data):
    """
    Create feature from last poll in each state
    """
    #adding topic
    
    # Only care about republicans
    repub = full_data[full_data["PARTY"] == "Rep"]
    repub = full_data[full_data["CHOICE"]!="Undecided"]
    
    # Sort by date
    chron = repub.sort_values(by="DATE", ascending=True)

    # Only keep the last one
    dedupe = chron.drop_duplicates(subset="STATE", keep="last")

    # Remove national polls
    return dedupe[dedupe["STATE"] != "US"]
    
if __name__ == "__main__":
    # Read in the X data
    all_data = pandas.read_csv("data.csv")

    # Remove non-states
    all_data = all_data[pandas.notnull(all_data["STATE"])]

    # split between testing and training
    train_x = last_poll(all_data[all_data["TOPIC"] == '2012-president'])

    test_x=train_x.tail(10)
    train_x=train_x.head(40)
    train_x.set_index("STATE")
    test_x.set_index("STATE")

    # Read in the Y data
    y_data = pandas.read_csv("../data/2012_pres.csv", sep=';')
    y_data = y_data[y_data["PARTY"] == "R"]
    y_data = y_data[pandas.notnull(y_data["GENERAL %"])]
    y_data["GENERAL %"] = [float(x.replace(",", ".").replace("%", ""))
                           for x in y_data["GENERAL %"]]
    y_data["STATE"] = y_data["STATE ABBREVIATION"]
    y_data.set_index("STATE")

    backup = train_x
    train_x = y_data.merge(train_x, on="STATE",how='left')
    
    # make sure we have all states in the test data
    for ii in set(y_data.STATE) - set(test_x.STATE):
        new_row = pandas.DataFrame([{"STATE": ii}])
        test_x = test_x.append(new_row)

    # format the data for regression
    train_x = pandas.concat([train_x.STATE.astype(str).str.get_dummies(),
                             train_x], axis=1)
    test_x = pandas.concat([test_x.STATE.astype(str).str.get_dummies(),
                             test_x], axis=1)
        
    # handle missing data
    for dd in train_x, test_x:                
        dd["NOPOLL"] = pandas.isnull(dd["VALUE"])
        dd["VALUE"] = dd["VALUE"].fillna(0.0)
        
    # create feature list
    features = list(y_data.STATE)
    features.append("VALUE")
    features.append("NOPOLL")    
        
    # fit the regression
    mod = linear_model.LinearRegression()
    mod.fit(train_x[features], train_x["GENERAL %"])

    # Write out the model
    with open("model.txt", 'w') as out:
        out.write("BIAS\t%f\n" % mod.intercept_)
        for jj, kk in zip(features, mod.coef_):
            out.write("%s\t%f\n" % (jj, kk))
    
    # Write the predictions
    pred_test = mod.predict(test_x[features])
    with open("pred.txt", 'w') as out:
        for ss, vv in sorted(zip(list(test_x.STATE), pred_test)):
            out.write("%s\t%f\n" % (ss, vv))

# %%
print("Mean squared error: %.2f"
      % numpy.mean((mod.predict(test_x[features]) - train_x["GENERAL %"]) ** 2))
#test data - train data
#(prediction - observed)^2
# Out:
# Mean squared error: 233.46

# %%
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f'
# 42438                Obama Health Care Law: Favor/Oppose   NaN
# 42439                               Party Identification   NaN
# 42440                               Party Identification   NaN
# 42441                               Party Identification   NaN
# 42442                               Party Identification   NaN
# 42443                               Party Identification   NaN
# 42444                               Party Identification   NaN
#
#                   SUBPOP  SUBPOPID                         CHOICE PARTY  \
# 0          Likely Voters         1                         Romney   Rep
# 1          Likely Voters         1                          Obama   Dem
# 2          Likely Voters         1                         Romney   Rep
# 3          Likely Voters         1                          Obama   Dem
# 4          Likely Voters         1                      Undecided   NaN
# 5          Likely Voters         1                          Other   NaN
# 6          Likely Voters         1                        Johnson   NaN
# 7          Likely Voters         1                      Undecided   NaN
# 8          Likely Voters         1                          Obama   Dem
# 9          Likely Voters         1                         Romney   Rep
# 10         Likely Voters         1                          Obama   Dem
# 11         Likely Voters         1                         Romney   Rep
# 12         Likely Voters         1                      Undecided   NaN
# 13         Likely Voters         1                      Undecided   NaN
# 14         Likely Voters         1                     Whitehouse   Dem
# 15         Likely Voters         1                       Hinckley   Rep
# 16     Registered Voters         1                        Approve   NaN
# 17     Registered Voters         1                     Disapprove   NaN
# 18         Likely Voters         1                         Romney   Rep
# 19         Likely Voters         1                      Undecided   NaN
# 20         Likely Voters         1                          Obama   Dem
# 21         Likely Voters         1                      Undecided   NaN
# 22         Likely Voters         1                          Obama   Dem
# 23         Likely Voters         1                         Romney   Rep
# 24         Likely Voters         1                        Approve   NaN
# 25         Likely Voters         1                     Disapprove   NaN
# 26         Likely Voters         1                      Undecided   NaN
# 27         Likely Voters         1                          Other   NaN
# 28         Likely Voters         1                         Romney   Rep
# 29         Likely Voters         1                          Obama   Dem
# ...                  ...       ...                            ...   ...
# 42415  Registered Voters         1  Hillary Clinton and Tim Kaine   Dem
# 42416  Registered Voters         1    Donald Trump and Mike Pence   Rep
# 42417  Registered Voters         1                   Gary Johnson   Lib
# 42418  Registered Voters         1                     Jill Stein   NaN
# 42419  Registered Voters         1                   Other (vol.)   NaN
# 42420  Registered Voters         1      Don't know/refused (vol.)   NaN
# 42421  Registered Voters         1  Hillary Clinton and Tim Kaine   Dem
# 42422  Registered Voters         1    Donald Trump and Mike Pence   Rep
# 42423  Registered Voters         1                   Other (vol.)   NaN
# 42424  Registered Voters         1      Don't know/refused (vol.)   NaN
# 42425             Adults         1                        Approve   NaN
# 42426             Adults         1                     Disapprove   NaN
# 42427             Adults         1                  DK/Ref (Vol.)   NaN
# 42428             Adults         1                      Favorable   NaN
# 42429             Adults         1                    Unfavorable   NaN
# 42430             Adults         1          Never heard of (vol).   NaN
# 42431             Adults         1      Can't rate/Refused (VOL.)   NaN
# 42432             Adults         1                      Favorable   NaN
# 42433             Adults         1                    Unfavorable   NaN
# 42434             Adults         1          Never Heard of (VOL.)   NaN
# 42435             Adults         1      Can't rate/Refused (VOL.)   NaN
# 42436             Adults         1                        Approve   NaN
# 42437             Adults         1                     Disapprove   NaN
# 42438             Adults         1                  DK/Ref (Vol.)   NaN
# 42439             Adults         1                     Republican   NaN
# 42440             Adults         1                       Democrat   NaN
# 42441             Adults         1                    independent   NaN
# 42442             Adults         1           No preference (vol.)   NaN
# 42443             Adults         1            Other party (vol.)    NaN
# 42444             Adults         1                  DK/Ref (Vol.)   NaN
#
#        VALUE     OBS STATE
# 0        8.0  1222.0    DC
# 1       88.0  1222.0    DC
# 2       63.0   625.0    ID
# 3       27.0   625.0    ID
# 4        6.0   625.0    ID
# 5        1.0   625.0    ID
# 6        3.0   625.0    ID
# 7        8.0   601.0    RI
# 8       54.0   601.0    RI
# 9       33.0   601.0    RI
# 10      58.0   471.0    RI
# 11      32.0   471.0    RI
# 12      10.0   471.0    RI
# 13      12.0   471.0    RI
# 14      59.0   471.0    RI
# 15      30.0   471.0    RI
# 16      54.0   496.0    RI
# 17      46.0   496.0    RI
# 18      33.0   501.0    RI
# 19       7.0   501.0    RI
# 20      57.0   501.0    RI
# 21      10.0   544.0    RI
# 22      54.0   544.0    RI
# 23      37.0   544.0    RI
# 24      53.0   544.0    RI
# 25      39.0   544.0    RI
# 26       8.0   544.0    RI
# 27       3.0   606.0    KY
# 28      53.0   606.0    KY
# 29      39.0   606.0    KY
# ...      ...     ...   ...
# 42415   46.0  2120.0    US
# 42416   40.0  2120.0    US
# 42417    6.0  2120.0    US
# 42418    3.0  2120.0    US
# 42419    2.0  2120.0    US
# 42420    4.0  2120.0    US
# 42421   50.0  2120.0    US
# 42422   43.0  2120.0    US
# 42423    3.0  2120.0    US
# 42424    4.0  2120.0    US
# 42425   54.0  2583.0    US
# 42426   42.0  2583.0    US
# 42427    5.0  2583.0    US
# 42428   40.0  2583.0    US
# 42429   55.0  2583.0    US
# 42430    0.0  2583.0    US
# 42431    5.0  2583.0    US
# 42432   52.0  2583.0    US
# 42433   45.0  2583.0    US
# 42434    0.0  2583.0    US
# 42435    4.0  2583.0    US
# 42436   46.0  2583.0    US
# 42437   51.0  2583.0    US
# 42438    4.0  2583.0    US
# 42439   26.0  2583.0    US
# 42440   33.0  2583.0    US
# 42441   36.0  2583.0    US
# 42442    3.0  2583.0    US
# 42443    0.0  2583.0    US
# 42444    2.0  2583.0    US
#
# [41600 rows x 12 columns]

# %%
if (all_data.TOPIC=="obama-job-approval"):
    print(all_data.TOPIC)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-ca673095032a> in <module>()
# ----> 1 if (all_data.TOPIC=="obama-job-approval"):
#       2     print(all_data.TOPIC)
#       3
#
# /home/rasmi/anaconda3/lib/python3.5/site-packages/pandas/core/generic.py in __nonzero__(self)
#     890         raise ValueError("The truth value of a {0} is ambiguous. "
#     891                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# --> 892                          .format(self.__class__.__name__))
#     893
#     894     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
